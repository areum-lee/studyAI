# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# a random guess : radom


x_data = [1.0, 2.0, 3.0]
y_data = [2.0, 4.0, 6.0]


# our model for the forward pass
def forward(x,w):
    return x * w


# Loss function
def loss(x, y,w):
    y_pred = forward(x,w)
    return (y_pred - y) * (y_pred - y)


w_list = []
mse_list = []

# 0부터 4.0 까지, 0.1 씩 돌면서.
for w in np.arange(0.0, 4.1, 0.1):
    print("w=", w)
    l_sum = 0
    for x_val, y_val in zip(x_data, y_data):
        y_pred_val = forward(x_val,w)
        l = loss(x_val, y_val,w)
        l_sum += l
        print("\t", x_val, y_val, y_pred_val, l)
        
    print("MSE=", l_sum / 3)
    w_list.append(w)
    mse_list.append(l_sum / 3)

plt.plot(w_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('w')
plt.show()
# Out:
# ('w=', 0.0)
# ('\t', 1.0, 2.0, 0.0, 4.0)
# ('\t', 2.0, 4.0, 0.0, 16.0)
# ('\t', 3.0, 6.0, 0.0, 36.0)
# ('MSE=', 18.666666666666668)
# ('w=', 0.10000000000000001)
# ('\t', 1.0, 2.0, 0.10000000000000001, 3.6099999999999999)
# ('\t', 2.0, 4.0, 0.20000000000000001, 14.44)
# ('\t', 3.0, 6.0, 0.30000000000000004, 32.490000000000002)
# ('MSE=', 16.846666666666668)
# ('w=', 0.20000000000000001)
# ('\t', 1.0, 2.0, 0.20000000000000001, 3.2400000000000002)
# ('\t', 2.0, 4.0, 0.40000000000000002, 12.960000000000001)
# ('\t', 3.0, 6.0, 0.60000000000000009, 29.160000000000004)
# ('MSE=', 15.120000000000003)
# ('w=', 0.30000000000000004)
# ('\t', 1.0, 2.0, 0.30000000000000004, 2.8899999999999997)
# ('\t', 2.0, 4.0, 0.60000000000000009, 11.559999999999999)
# ('\t', 3.0, 6.0, 0.90000000000000013, 26.009999999999998)
# ('MSE=', 13.486666666666665)
# ('w=', 0.40000000000000002)
# ('\t', 1.0, 2.0, 0.40000000000000002, 2.5600000000000005)
# ('\t', 2.0, 4.0, 0.80000000000000004, 10.240000000000002)
# ('\t', 3.0, 6.0, 1.2000000000000002, 23.039999999999999)
# ('MSE=', 11.946666666666667)
# ('w=', 0.5)
# ('\t', 1.0, 2.0, 0.5, 2.25)
# ('\t', 2.0, 4.0, 1.0, 9.0)
# ('\t', 3.0, 6.0, 1.5, 20.25)
# ('MSE=', 10.5)
# ('w=', 0.60000000000000009)
# ('\t', 1.0, 2.0, 0.60000000000000009, 1.9599999999999997)
# ('\t', 2.0, 4.0, 1.2000000000000002, 7.839999999999999)
# ('\t', 3.0, 6.0, 1.8000000000000003, 17.639999999999993)
# ('MSE=', 9.1466666666666629)
# ('w=', 0.70000000000000007)
# ('\t', 1.0, 2.0, 0.70000000000000007, 1.6899999999999995)
# ('\t', 2.0, 4.0, 1.4000000000000001, 6.759999999999998)
# ('\t', 3.0, 6.0, 2.1000000000000001, 15.209999999999999)
# ('MSE=', 7.8866666666666658)
# ('w=', 0.80000000000000004)
# ('\t', 1.0, 2.0, 0.80000000000000004, 1.4399999999999999)
# ('\t', 2.0, 4.0, 1.6000000000000001, 5.7599999999999998)
# ('\t', 3.0, 6.0, 2.4000000000000004, 12.959999999999997)
# ('MSE=', 6.7199999999999989)
# ('w=', 0.90000000000000002)
# ('\t', 1.0, 2.0, 0.90000000000000002, 1.2100000000000002)
# ('\t', 2.0, 4.0, 1.8, 4.8400000000000007)
# ('\t', 3.0, 6.0, 2.7000000000000002, 10.889999999999999)
# ('MSE=', 5.6466666666666656)
# ('w=', 1.0)
# ('\t', 1.0, 2.0, 1.0, 1.0)
# ('\t', 2.0, 4.0, 2.0, 4.0)
# ('\t', 3.0, 6.0, 3.0, 9.0)
# ('MSE=', 4.666666666666667)
# ('w=', 1.1000000000000001)
# ('\t', 1.0, 2.0, 1.1000000000000001, 0.80999999999999983)
# ('\t', 2.0, 4.0, 2.2000000000000002, 3.2399999999999993)
# ('\t', 3.0, 6.0, 3.3000000000000003, 7.2899999999999983)
# ('MSE=', 3.7799999999999989)
# ('w=', 1.2000000000000002)
# ('\t', 1.0, 2.0, 1.2000000000000002, 0.63999999999999968)
# ('\t', 2.0, 4.0, 2.4000000000000004, 2.5599999999999987)
# ('\t', 3.0, 6.0, 3.6000000000000005, 5.7599999999999971)
# ('MSE=', 2.986666666666665)
# ('w=', 1.3)
# ('\t', 1.0, 2.0, 1.3, 0.48999999999999994)
# ('\t', 2.0, 4.0, 2.6000000000000001, 1.9599999999999997)
# ('\t', 3.0, 6.0, 3.9000000000000004, 4.4099999999999984)
# ('MSE=', 2.2866666666666657)
# ('w=', 1.4000000000000001)
# ('\t', 1.0, 2.0, 1.4000000000000001, 0.35999999999999982)
# ('\t', 2.0, 4.0, 2.8000000000000003, 1.4399999999999993)
# ('\t', 3.0, 6.0, 4.2000000000000002, 3.2399999999999993)
# ('MSE=', 1.6799999999999995)
# ('w=', 1.5)
# ('\t', 1.0, 2.0, 1.5, 0.25)
# ('\t', 2.0, 4.0, 3.0, 1.0)
# ('\t', 3.0, 6.0, 4.5, 2.25)
# ('MSE=', 1.1666666666666667)
# ('w=', 1.6000000000000001)
# ('\t', 1.0, 2.0, 1.6000000000000001, 0.15999999999999992)
# ('\t', 2.0, 4.0, 3.2000000000000002, 0.63999999999999968)
# ('\t', 3.0, 6.0, 4.8000000000000007, 1.4399999999999984)
# ('MSE=', 0.74666666666666603)
# ('w=', 1.7000000000000002)
# ('\t', 1.0, 2.0, 1.7000000000000002, 0.0899999999999999)
# ('\t', 2.0, 4.0, 3.4000000000000004, 0.3599999999999996)
# ('\t', 3.0, 6.0, 5.1000000000000005, 0.80999999999999905)
# ('MSE=', 0.41999999999999948)
# ('w=', 1.8)
# ('\t', 1.0, 2.0, 1.8, 0.03999999999999998)
# ('\t', 2.0, 4.0, 3.6000000000000001, 0.15999999999999992)
# ('\t', 3.0, 6.0, 5.4000000000000004, 0.3599999999999996)
# ('MSE=', 0.18666666666666651)
# ('w=', 1.9000000000000001)
# ('\t', 1.0, 2.0, 1.9000000000000001, 0.0099999999999999742)
# ('\t', 2.0, 4.0, 3.8000000000000003, 0.039999999999999897)
# ('\t', 3.0, 6.0, 5.7000000000000002, 0.0899999999999999)
# ('MSE=', 0.046666666666666586)
# ('w=', 2.0)
# ('\t', 1.0, 2.0, 2.0, 0.0)
# ('\t', 2.0, 4.0, 4.0, 0.0)
# ('\t', 3.0, 6.0, 6.0, 0.0)
# ('MSE=', 0.0)
# ('w=', 2.1000000000000001)
# ('\t', 1.0, 2.0, 2.1000000000000001, 0.010000000000000018)
# ('\t', 2.0, 4.0, 4.2000000000000002, 0.04000000000000007)
# ('\t', 3.0, 6.0, 6.3000000000000007, 0.090000000000000427)
# ('MSE=', 0.046666666666666835)
# ('w=', 2.2000000000000002)
# ('\t', 1.0, 2.0, 2.2000000000000002, 0.04000000000000007)
# ('\t', 2.0, 4.0, 4.4000000000000004, 0.16000000000000028)
# ('\t', 3.0, 6.0, 6.6000000000000005, 0.36000000000000065)
# ('MSE=', 0.18666666666666698)
# ('w=', 2.3000000000000003)
# ('\t', 1.0, 2.0, 2.3000000000000003, 0.090000000000000163)
# ('\t', 2.0, 4.0, 4.6000000000000005, 0.36000000000000065)
# ('\t', 3.0, 6.0, 6.9000000000000004, 0.81000000000000061)
# ('MSE=', 0.42000000000000054)
# ('w=', 2.4000000000000004)
# ('\t', 1.0, 2.0, 2.4000000000000004, 0.16000000000000028)
# ('\t', 2.0, 4.0, 4.8000000000000007, 0.64000000000000112)
# ('\t', 3.0, 6.0, 7.2000000000000011, 1.4400000000000026)
# ('MSE=', 0.74666666666666792)
# ('w=', 2.5)
# ('\t', 1.0, 2.0, 2.5, 0.25)
# ('\t', 2.0, 4.0, 5.0, 1.0)
# ('\t', 3.0, 6.0, 7.5, 2.25)
# ('MSE=', 1.1666666666666667)
# ('w=', 2.6000000000000001)
# ('\t', 1.0, 2.0, 2.6000000000000001, 0.3600000000000001)
# ('\t', 2.0, 4.0, 5.2000000000000002, 1.4400000000000004)
# ('\t', 3.0, 6.0, 7.8000000000000007, 3.2400000000000024)
# ('MSE=', 1.6800000000000008)
# ('w=', 2.7000000000000002)
# ('\t', 1.0, 2.0, 2.7000000000000002, 0.49000000000000027)
# ('\t', 2.0, 4.0, 5.4000000000000004, 1.9600000000000011)
# ('\t', 3.0, 6.0, 8.1000000000000014, 4.4100000000000064)
# ('MSE=', 2.2866666666666693)
# ('w=', 2.8000000000000003)
# ('\t', 1.0, 2.0, 2.8000000000000003, 0.64000000000000046)
# ('\t', 2.0, 4.0, 5.6000000000000005, 2.5600000000000018)
# ('\t', 3.0, 6.0, 8.4000000000000004, 5.7600000000000016)
# ('MSE=', 2.9866666666666681)
# ('w=', 2.9000000000000004)
# ('\t', 1.0, 2.0, 2.9000000000000004, 0.81000000000000061)
# ('\t', 2.0, 4.0, 5.8000000000000007, 3.2400000000000024)
# ('\t', 3.0, 6.0, 8.7000000000000011, 7.2900000000000054)
# ('MSE=', 3.7800000000000029)
# ('w=', 3.0)
# ('\t', 1.0, 2.0, 3.0, 1.0)
# ('\t', 2.0, 4.0, 6.0, 4.0)
# ('\t', 3.0, 6.0, 9.0, 9.0)
# ('MSE=', 4.666666666666667)
# ('w=', 3.1000000000000001)
# ('\t', 1.0, 2.0, 3.1000000000000001, 1.2100000000000002)
# ('\t', 2.0, 4.0, 6.2000000000000002, 4.8400000000000007)
# ('\t', 3.0, 6.0, 9.3000000000000007, 10.890000000000004)
# ('MSE=', 5.6466666666666683)
# ('w=', 3.2000000000000002)
# ('\t', 1.0, 2.0, 3.2000000000000002, 1.4400000000000004)
# ('\t', 2.0, 4.0, 6.4000000000000004, 5.7600000000000016)
# ('\t', 3.0, 6.0, 9.6000000000000014, 12.96000000000001)
# ('MSE=', 6.7200000000000033)
# ('w=', 3.3000000000000003)
# ('\t', 1.0, 2.0, 3.3000000000000003, 1.6900000000000006)
# ('\t', 2.0, 4.0, 6.6000000000000005, 6.7600000000000025)
# ('\t', 3.0, 6.0, 9.9000000000000004, 15.210000000000003)
# ('MSE=', 7.8866666666666676)
# ('w=', 3.4000000000000004)
# ('\t', 1.0, 2.0, 3.4000000000000004, 1.9600000000000011)
# ('\t', 2.0, 4.0, 6.8000000000000007, 7.8400000000000043)
# ('\t', 3.0, 6.0, 10.200000000000001, 17.640000000000008)
# ('MSE=', 9.1466666666666701)
# ('w=', 3.5)
# ('\t', 1.0, 2.0, 3.5, 2.25)
# ('\t', 2.0, 4.0, 7.0, 9.0)
# ('\t', 3.0, 6.0, 10.5, 20.25)
# ('MSE=', 10.5)
# ('w=', 3.6000000000000001)
# ('\t', 1.0, 2.0, 3.6000000000000001, 2.5600000000000005)
# ('\t', 2.0, 4.0, 7.2000000000000002, 10.240000000000002)
# ('\t', 3.0, 6.0, 10.800000000000001, 23.040000000000006)
# ('MSE=', 11.946666666666671)
# ('w=', 3.7000000000000002)
# ('\t', 1.0, 2.0, 3.7000000000000002, 2.8900000000000006)
# ('\t', 2.0, 4.0, 7.4000000000000004, 11.560000000000002)
# ('\t', 3.0, 6.0, 11.100000000000001, 26.010000000000016)
# ('MSE=', 13.486666666666673)
# ('w=', 3.8000000000000003)
# ('\t', 1.0, 2.0, 3.8000000000000003, 3.2400000000000011)
# ('\t', 2.0, 4.0, 7.6000000000000005, 12.960000000000004)
# ('\t', 3.0, 6.0, 11.4, 29.160000000000004)
# ('MSE=', 15.120000000000005)
# ('w=', 3.9000000000000004)
# ('\t', 1.0, 2.0, 3.9000000000000004, 3.6100000000000012)
# ('\t', 2.0, 4.0, 7.8000000000000007, 14.440000000000005)
# ('\t', 3.0, 6.0, 11.700000000000001, 32.490000000000009)
# ('MSE=', 16.846666666666671)
# ('w=', 4.0)
# ('\t', 1.0, 2.0, 4.0, 4.0)
# ('\t', 2.0, 4.0, 8.0, 16.0)
# ('\t', 3.0, 6.0, 12.0, 36.0)
# ('MSE=', 18.666666666666668)

# %%
def forward(x,w):
    return x*w

def loss(x,y,w):
    y_pred = forward(x,w)
    return (y_pred - y)*(y_pred -y)

w_list=[]
mse_list=[]

# range 가 아닌 np.arange
for w in np.arange(0.0,4.1,0.1):
    print ("w=",w)
    l_sum = 0
    for x_val, y_val in zip(x_data,y_data):
        y_pred_val = forward(x_val,w)
        l = loss (x_val, y_val,w)
        l_sum += l
    print ("MSE ", l_sum / len(x_data))
    w_list.append(w)
    mse_list.append(l_sum/len(x_data))
    
plt.plot(w_list,mse_list)
plt.show()
# Out:
# ('w=', 0.0)
# ('MSE ', 18.666666666666668)
# ('w=', 0.10000000000000001)
# ('MSE ', 16.846666666666668)
# ('w=', 0.20000000000000001)
# ('MSE ', 15.120000000000003)
# ('w=', 0.30000000000000004)
# ('MSE ', 13.486666666666665)
# ('w=', 0.40000000000000002)
# ('MSE ', 11.946666666666667)
# ('w=', 0.5)
# ('MSE ', 10.5)
# ('w=', 0.60000000000000009)
# ('MSE ', 9.1466666666666629)
# ('w=', 0.70000000000000007)
# ('MSE ', 7.8866666666666658)
# ('w=', 0.80000000000000004)
# ('MSE ', 6.7199999999999989)
# ('w=', 0.90000000000000002)
# ('MSE ', 5.6466666666666656)
# ('w=', 1.0)
# ('MSE ', 4.666666666666667)
# ('w=', 1.1000000000000001)
# ('MSE ', 3.7799999999999989)
# ('w=', 1.2000000000000002)
# ('MSE ', 2.986666666666665)
# ('w=', 1.3)
# ('MSE ', 2.2866666666666657)
# ('w=', 1.4000000000000001)
# ('MSE ', 1.6799999999999995)
# ('w=', 1.5)
# ('MSE ', 1.1666666666666667)
# ('w=', 1.6000000000000001)
# ('MSE ', 0.74666666666666603)
# ('w=', 1.7000000000000002)
# ('MSE ', 0.41999999999999948)
# ('w=', 1.8)
# ('MSE ', 0.18666666666666651)
# ('w=', 1.9000000000000001)
# ('MSE ', 0.046666666666666586)
# ('w=', 2.0)
# ('MSE ', 0.0)
# ('w=', 2.1000000000000001)
# ('MSE ', 0.046666666666666835)
# ('w=', 2.2000000000000002)
# ('MSE ', 0.18666666666666698)
# ('w=', 2.3000000000000003)
# ('MSE ', 0.42000000000000054)
# ('w=', 2.4000000000000004)
# ('MSE ', 0.74666666666666792)
# ('w=', 2.5)
# ('MSE ', 1.1666666666666667)
# ('w=', 2.6000000000000001)
# ('MSE ', 1.6800000000000008)
# ('w=', 2.7000000000000002)
# ('MSE ', 2.2866666666666693)
# ('w=', 2.8000000000000003)
# ('MSE ', 2.9866666666666681)
# ('w=', 2.9000000000000004)
# ('MSE ', 3.7800000000000029)
# ('w=', 3.0)
# ('MSE ', 4.666666666666667)
# ('w=', 3.1000000000000001)
# ('MSE ', 5.6466666666666683)
# ('w=', 3.2000000000000002)
# ('MSE ', 6.7200000000000033)
# ('w=', 3.3000000000000003)
# ('MSE ', 7.8866666666666676)
# ('w=', 3.4000000000000004)
# ('MSE ', 9.1466666666666701)
# ('w=', 3.5)
# ('MSE ', 10.5)
# ('w=', 3.6000000000000001)
# ('MSE ', 11.946666666666671)
# ('w=', 3.7000000000000002)
# ('MSE ', 13.486666666666673)
# ('w=', 3.8000000000000003)
# ('MSE ', 15.120000000000005)
# ('w=', 3.9000000000000004)
# ('MSE ', 16.846666666666671)
# ('w=', 4.0)
# ('MSE ', 18.666666666666668)
